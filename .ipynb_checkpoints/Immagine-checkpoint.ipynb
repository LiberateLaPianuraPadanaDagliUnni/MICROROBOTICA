# %% [markdown]
# # Immagini con plt
# 14/10/25

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img=plt.imread("./immagine1.png")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (274, 366, 4)

# %%
img.dtype
# Out:
# dtype('float32')

# %%
img
# Out:
# array([[[0.96862745, 0.96862745, 0.972549  , 1.        ],
#         [0.96862745, 0.96862745, 0.972549  , 1.        ],
#         [0.96862745, 0.96862745, 0.972549  , 1.        ],
#         ...,
#         [0.96862745, 0.96862745, 0.972549  , 1.        ],
#         [0.96862745, 0.96862745, 0.972549  , 1.        ],
#         [0.96862745, 0.96862745, 0.972549  , 1.        ]],
#
#        [[0.96862745, 0.96862745, 0.972549  , 1.        ],
#         [0.96862745, 0.96862745, 0.972549  , 1.        ],
#         [0.96862745, 0.96862745, 0.972549  , 1.        ],
#         ...,
#         [0.96862745, 0.96862745, 0.972549  , 1.        ],
#         [0.96862745, 0.96862745, 0.972549  , 1.        ],
#         [0.96862745, 0.96862745, 0.972549  , 1.        ]],
#
#        [[0.96862745, 0.96862745, 0.972549  , 1.        ],
#         [0.96862745, 0.96862745, 0.972549  , 1.        ],
#         [0.96862745, 0.96862745, 0.972549  , 1.        ],
#         ...,
# ...

# %%
plt.imshow(img)

# %%
red=img[:,:,0]

# %%
np.max(red)
# Out:
# np.float32(1.0)

# %%
np.min(red)
# Out:
# np.float32(0.0)

# %%
plt.imshow(red, cmap="Greys")

# %%
img[:,:,2]=0
plt.imshow(img)

# %%
img[:,:,2]=0.5
plt.imshow(img)

# %%
img[:,:,2]=1
plt.imshow(img)

# %%
img[0:50,50:70,:]=0
plt.imshow(img)

# %%
img[0:270,163:203,:]=1
plt.imshow(img)
